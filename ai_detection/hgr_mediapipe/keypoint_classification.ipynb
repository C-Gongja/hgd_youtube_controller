# %%
import csv

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

RANDOM_SEED = 42
# Out:
# 2023-12-29 22:37:46.681481: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 各パス指定 (specify individual paths)

# %%
dataset = 'model/keypoint_classifier/keypoint.csv'
model_save_path = 'model/keypoint_classifier/keypoint_classifier.hdf5'

# %% [markdown]
# # 分類数設定

# %%
NUM_CLASSES = 6

# %% [markdown]
# # 学習データ読み込み (loading training data)

# %%
X_dataset = np.loadtxt(dataset, delimiter=',', dtype='float32', usecols=list(range(1, (21 * 2) + 1)))

# %%
y_dataset = np.loadtxt(dataset, delimiter=',', dtype='int32', usecols=(0))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, train_size=0.75, random_state=RANDOM_SEED)

# %% [markdown]
# # モデル構築 (Model Construction)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((21 * 2, )),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(20, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
model.summary()  # tf.keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dropout (Dropout)           (None, 42)                0
#
#  dense (Dense)               (None, 20)                860
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 6)                 66
#
# =================================================================
# Total params: 1136 (4.44 KB)
# Trainable params: 1136 (4.44 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# モデルチェックポイントのコールバック
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    model_save_path, verbose=1, save_weights_only=False)
# 早期打ち切り用コールバック
es_callback = tf.keras.callbacks.EarlyStopping(patience=20, verbose=1)

# %%
# モデルコンパイル
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # モデル訓練

# %%
model.fit(
    X_train,
    y_train,
    epochs=1000,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[cp_callback, es_callback]
)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.7785 - accuracy: 0.0000e+00
# Epoch 1: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 2s 2s/step - loss: 1.7785 - accuracy: 0.0000e+00 - val_loss: 1.6107 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.4071 - accuracy: 0.0000e+00
# Epoch 2: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.4071 - accuracy: 0.0000e+00 - val_loss: 1.5833 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.7502 - accuracy: 0.0000e+00
# Epoch 3: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 1.7502 - accuracy: 0.0000e+00 - val_loss: 1.5584 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.6687 - accuracy: 0.0000e+00
# /Users/yoon/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 4: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.6687 - accuracy: 0.0000e+00 - val_loss: 1.5324 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.6525 - accuracy: 0.0000e+00
# Epoch 5: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.6525 - accuracy: 0.0000e+00 - val_loss: 1.5057 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.5192 - accuracy: 0.0000e+00
# Epoch 6: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.5192 - accuracy: 0.0000e+00 - val_loss: 1.4794 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.6304 - accuracy: 0.0000e+00
# Epoch 7: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 1.6304 - accuracy: 0.0000e+00 - val_loss: 1.4529 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.4890 - accuracy: 0.0000e+00
# Epoch 8: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 1.4890 - accuracy: 0.0000e+00 - val_loss: 1.4288 - val_accuracy: 0.0000e+00
# Epoch 9/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.5687 - accuracy: 0.0000e+00
# Epoch 9: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.5687 - accuracy: 0.0000e+00 - val_loss: 1.4158 - val_accuracy: 0.0000e+00
# Epoch 10/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.4870 - accuracy: 0.0000e+00
# Epoch 10: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.4870 - accuracy: 0.0000e+00 - val_loss: 1.4025 - val_accuracy: 0.0000e+00
# Epoch 11/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.3329 - accuracy: 0.0000e+00
# Epoch 11: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3329 - accuracy: 0.0000e+00 - val_loss: 1.3893 - val_accuracy: 0.0000e+00
# Epoch 12/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.3801 - accuracy: 0.0000e+00
# Epoch 12: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 1.3801 - accuracy: 0.0000e+00 - val_loss: 1.3765 - val_accuracy: 0.0000e+00
# Epoch 13/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2966 - accuracy: 0.0000e+00
# Epoch 13: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.2966 - accuracy: 0.0000e+00 - val_loss: 1.3637 - val_accuracy: 0.0000e+00
# Epoch 14/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.3860 - accuracy: 0.0000e+00
# Epoch 14: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 1.3860 - accuracy: 0.0000e+00 - val_loss: 1.3509 - val_accuracy: 0.0000e+00
# Epoch 15/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.3167 - accuracy: 0.0000e+00
# Epoch 15: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.3167 - accuracy: 0.0000e+00 - val_loss: 1.3374 - val_accuracy: 0.0000e+00
# Epoch 16/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2715 - accuracy: 0.3333
# Epoch 16: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 94ms/step - loss: 1.2715 - accuracy: 0.3333 - val_loss: 1.3233 - val_accuracy: 0.0000e+00
# Epoch 17/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.4524 - accuracy: 0.0000e+00
# Epoch 17: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 1.4524 - accuracy: 0.0000e+00 - val_loss: 1.3089 - val_accuracy: 0.0000e+00
# Epoch 18/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.3633 - accuracy: 0.3333
# Epoch 18: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 70ms/step - loss: 1.3633 - accuracy: 0.3333 - val_loss: 1.2944 - val_accuracy: 0.0000e+00
# Epoch 19/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2280 - accuracy: 0.3333
# Epoch 19: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.2280 - accuracy: 0.3333 - val_loss: 1.2798 - val_accuracy: 0.0000e+00
# Epoch 20/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.1519 - accuracy: 0.0000e+00
# Epoch 20: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 1.1519 - accuracy: 0.0000e+00 - val_loss: 1.2654 - val_accuracy: 0.0000e+00
# Epoch 21/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.1135 - accuracy: 0.3333
# Epoch 21: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 82ms/step - loss: 1.1135 - accuracy: 0.3333 - val_loss: 1.2510 - val_accuracy: 0.0000e+00
# Epoch 22/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2611 - accuracy: 0.3333
# Epoch 22: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 1.2611 - accuracy: 0.3333 - val_loss: 1.2365 - val_accuracy: 0.0000e+00
# Epoch 23/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2029 - accuracy: 0.0000e+00
# Epoch 23: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.2029 - accuracy: 0.0000e+00 - val_loss: 1.2221 - val_accuracy: 0.0000e+00
# Epoch 24/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2289 - accuracy: 0.0000e+00
# Epoch 24: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 81ms/step - loss: 1.2289 - accuracy: 0.0000e+00 - val_loss: 1.2076 - val_accuracy: 0.0000e+00
# Epoch 25/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2929 - accuracy: 0.0000e+00
# Epoch 25: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 1.2929 - accuracy: 0.0000e+00 - val_loss: 1.1930 - val_accuracy: 0.0000e+00
# Epoch 26/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.0924 - accuracy: 1.0000
# Epoch 26: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 1.0924 - accuracy: 1.0000 - val_loss: 1.1784 - val_accuracy: 0.0000e+00
# Epoch 27/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.1390 - accuracy: 0.3333
# Epoch 27: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.1390 - accuracy: 0.3333 - val_loss: 1.1638 - val_accuracy: 0.0000e+00
# Epoch 28/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.0176 - accuracy: 0.6667
# Epoch 28: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 1.0176 - accuracy: 0.6667 - val_loss: 1.1494 - val_accuracy: 0.0000e+00
# Epoch 29/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.2474 - accuracy: 0.3333
# Epoch 29: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 1.2474 - accuracy: 0.3333 - val_loss: 1.1351 - val_accuracy: 0.0000e+00
# Epoch 30/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.1684 - accuracy: 0.0000e+00
# Epoch 30: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 1.1684 - accuracy: 0.0000e+00 - val_loss: 1.1208 - val_accuracy: 0.0000e+00
# Epoch 31/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.9381 - accuracy: 0.6667
# Epoch 31: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.9381 - accuracy: 0.6667 - val_loss: 1.1064 - val_accuracy: 0.0000e+00
# Epoch 32/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.0193 - accuracy: 0.3333
# Epoch 32: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 1.0193 - accuracy: 0.3333 - val_loss: 1.0922 - val_accuracy: 1.0000
# Epoch 33/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.1440 - accuracy: 0.0000e+00
# Epoch 33: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.1440 - accuracy: 0.0000e+00 - val_loss: 1.0782 - val_accuracy: 1.0000
# Epoch 34/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.9216 - accuracy: 0.6667
# Epoch 34: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.9216 - accuracy: 0.6667 - val_loss: 1.0644 - val_accuracy: 1.0000
# Epoch 35/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.0530 - accuracy: 0.3333
# Epoch 35: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 1.0530 - accuracy: 0.3333 - val_loss: 1.0502 - val_accuracy: 1.0000
# Epoch 36/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.9151 - accuracy: 1.0000
# Epoch 36: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.9151 - accuracy: 1.0000 - val_loss: 1.0346 - val_accuracy: 1.0000
# Epoch 37/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8537 - accuracy: 0.6667
# Epoch 37: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.8537 - accuracy: 0.6667 - val_loss: 1.0152 - val_accuracy: 1.0000
# Epoch 38/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.0803 - accuracy: 1.0000
# Epoch 38: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 91ms/step - loss: 1.0803 - accuracy: 1.0000 - val_loss: 0.9950 - val_accuracy: 1.0000
# Epoch 39/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8141 - accuracy: 0.6667
# Epoch 39: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.8141 - accuracy: 0.6667 - val_loss: 0.9654 - val_accuracy: 1.0000
# Epoch 40/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8770 - accuracy: 1.0000
# Epoch 40: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 104ms/step - loss: 0.8770 - accuracy: 1.0000 - val_loss: 0.9359 - val_accuracy: 1.0000
# Epoch 41/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.9914 - accuracy: 0.6667
# Epoch 41: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.9914 - accuracy: 0.6667 - val_loss: 0.9046 - val_accuracy: 1.0000
# Epoch 42/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8388 - accuracy: 0.6667
# Epoch 42: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.8388 - accuracy: 0.6667 - val_loss: 0.8735 - val_accuracy: 1.0000
# Epoch 43/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8829 - accuracy: 0.6667
# Epoch 43: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.8829 - accuracy: 0.6667 - val_loss: 0.8424 - val_accuracy: 1.0000
# Epoch 44/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.7874 - accuracy: 1.0000
# Epoch 44: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.7874 - accuracy: 1.0000 - val_loss: 0.8125 - val_accuracy: 1.0000
# Epoch 45/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8173 - accuracy: 1.0000
# Epoch 45: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 82ms/step - loss: 0.8173 - accuracy: 1.0000 - val_loss: 0.7826 - val_accuracy: 1.0000
# Epoch 46/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 1.0000
# Epoch 46: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.7049 - accuracy: 1.0000 - val_loss: 0.7530 - val_accuracy: 1.0000
# Epoch 47/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8381 - accuracy: 1.0000
# Epoch 47: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.8381 - accuracy: 1.0000 - val_loss: 0.7242 - val_accuracy: 1.0000
# Epoch 48/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8119 - accuracy: 1.0000
# Epoch 48: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.8119 - accuracy: 1.0000 - val_loss: 0.6959 - val_accuracy: 1.0000
# Epoch 49/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.6747 - accuracy: 1.0000
# Epoch 49: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 84ms/step - loss: 0.6747 - accuracy: 1.0000 - val_loss: 0.6683 - val_accuracy: 1.0000
# Epoch 50/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.7930 - accuracy: 1.0000
# Epoch 50: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 99ms/step - loss: 0.7930 - accuracy: 1.0000 - val_loss: 0.6419 - val_accuracy: 1.0000
# Epoch 51/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.7626 - accuracy: 1.0000
# Epoch 51: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 94ms/step - loss: 0.7626 - accuracy: 1.0000 - val_loss: 0.6156 - val_accuracy: 1.0000
# Epoch 52/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.8532 - accuracy: 1.0000
# Epoch 52: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 123ms/step - loss: 0.8532 - accuracy: 1.0000 - val_loss: 0.5892 - val_accuracy: 1.0000
# Epoch 53/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.5543 - accuracy: 1.0000
# Epoch 53: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 89ms/step - loss: 0.5543 - accuracy: 1.0000 - val_loss: 0.5633 - val_accuracy: 1.0000
# Epoch 54/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.5559 - accuracy: 1.0000
# Epoch 54: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5559 - accuracy: 1.0000 - val_loss: 0.5377 - val_accuracy: 1.0000
# Epoch 55/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 1.0000
# Epoch 55: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6950 - accuracy: 1.0000 - val_loss: 0.5127 - val_accuracy: 1.0000
# Epoch 56/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.4184 - accuracy: 1.0000
# Epoch 56: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4184 - accuracy: 1.0000 - val_loss: 0.4880 - val_accuracy: 1.0000
# Epoch 57/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 1.0000
# Epoch 57: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.5346 - accuracy: 1.0000 - val_loss: 0.4639 - val_accuracy: 1.0000
# Epoch 58/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.6442 - accuracy: 1.0000
# Epoch 58: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.6442 - accuracy: 1.0000 - val_loss: 0.4406 - val_accuracy: 1.0000
# Epoch 59/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.4826 - accuracy: 1.0000
# Epoch 59: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4826 - accuracy: 1.0000 - val_loss: 0.4187 - val_accuracy: 1.0000
# Epoch 60/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3775 - accuracy: 1.0000
# Epoch 60: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.3775 - accuracy: 1.0000 - val_loss: 0.3969 - val_accuracy: 1.0000
# Epoch 61/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2671 - accuracy: 1.0000
# Epoch 61: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2671 - accuracy: 1.0000 - val_loss: 0.3757 - val_accuracy: 1.0000
# Epoch 62/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.5215 - accuracy: 1.0000
# Epoch 62: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.5215 - accuracy: 1.0000 - val_loss: 0.3551 - val_accuracy: 1.0000
# Epoch 63/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 1.0000
# Epoch 63: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3993 - accuracy: 1.0000 - val_loss: 0.3351 - val_accuracy: 1.0000
# Epoch 64/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.5101 - accuracy: 1.0000
# Epoch 64: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.5101 - accuracy: 1.0000 - val_loss: 0.3162 - val_accuracy: 1.0000
# Epoch 65/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 1.0000
# Epoch 65: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.3159 - accuracy: 1.0000 - val_loss: 0.2978 - val_accuracy: 1.0000
# Epoch 66/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 1.0000
# Epoch 66: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2595 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 1.0000
# Epoch 67/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3666 - accuracy: 1.0000
# Epoch 67: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.3666 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 1.0000
# Epoch 68/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.4138 - accuracy: 1.0000
# Epoch 68: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4138 - accuracy: 1.0000 - val_loss: 0.2478 - val_accuracy: 1.0000
# Epoch 69/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3053 - accuracy: 1.0000
# Epoch 69: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.3053 - accuracy: 1.0000 - val_loss: 0.2323 - val_accuracy: 1.0000
# Epoch 70/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3026 - accuracy: 1.0000
# Epoch 70: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.3026 - accuracy: 1.0000 - val_loss: 0.2180 - val_accuracy: 1.0000
# Epoch 71/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 1.0000
# Epoch 71: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.2655 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 1.0000
# Epoch 72/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.4136 - accuracy: 1.0000
# Epoch 72: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4136 - accuracy: 1.0000 - val_loss: 0.1918 - val_accuracy: 1.0000
# Epoch 73/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 1.0000
# Epoch 73: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.1973 - accuracy: 1.0000 - val_loss: 0.1800 - val_accuracy: 1.0000
# Epoch 74/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 1.0000
# Epoch 74: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.2267 - accuracy: 1.0000 - val_loss: 0.1690 - val_accuracy: 1.0000
# Epoch 75/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 1.0000
# Epoch 75: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.2918 - accuracy: 1.0000 - val_loss: 0.1588 - val_accuracy: 1.0000
# Epoch 76/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2093 - accuracy: 1.0000
# Epoch 76: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.2093 - accuracy: 1.0000 - val_loss: 0.1492 - val_accuracy: 1.0000
# Epoch 77/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3208 - accuracy: 1.0000
# Epoch 77: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.3208 - accuracy: 1.0000 - val_loss: 0.1402 - val_accuracy: 1.0000
# Epoch 78/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 1.0000
# Epoch 78: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2961 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 1.0000
# Epoch 79/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 1.0000
# Epoch 79: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.3011 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 1.0000
# Epoch 80/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1449 - accuracy: 1.0000
# Epoch 80: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1449 - accuracy: 1.0000 - val_loss: 0.1169 - val_accuracy: 1.0000
# Epoch 81/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 1.0000
# Epoch 81: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1447 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 1.0000
# Epoch 82/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 1.0000
# Epoch 82: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1660 - accuracy: 1.0000 - val_loss: 0.1038 - val_accuracy: 1.0000
# Epoch 83/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.5864 - accuracy: 1.0000
# Epoch 83: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.5864 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 84/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0893 - accuracy: 1.0000
# Epoch 84: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0893 - accuracy: 1.0000 - val_loss: 0.0924 - val_accuracy: 1.0000
# Epoch 85/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1154 - accuracy: 1.0000
# Epoch 85: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1154 - accuracy: 1.0000 - val_loss: 0.0873 - val_accuracy: 1.0000
# Epoch 86/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 1.0000
# Epoch 86: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.3048 - accuracy: 1.0000 - val_loss: 0.0827 - val_accuracy: 1.0000
# Epoch 87/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0868 - accuracy: 1.0000
# Epoch 87: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0868 - accuracy: 1.0000 - val_loss: 0.0784 - val_accuracy: 1.0000
# Epoch 88/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1057 - accuracy: 1.0000
# Epoch 88: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1057 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 1.0000
# Epoch 89/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0379 - accuracy: 1.0000
# Epoch 89: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.0708 - val_accuracy: 1.0000
# Epoch 90/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 1.0000
# Epoch 90: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1752 - accuracy: 1.0000 - val_loss: 0.0673 - val_accuracy: 1.0000
# Epoch 91/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 1.0000
# Epoch 91: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0524 - accuracy: 1.0000 - val_loss: 0.0641 - val_accuracy: 1.0000
# Epoch 92/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1632 - accuracy: 1.0000
# Epoch 92: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1632 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 1.0000
# Epoch 93/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 1.0000
# Epoch 93: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.1988 - accuracy: 1.0000 - val_loss: 0.0579 - val_accuracy: 1.0000
# Epoch 94/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1266 - accuracy: 1.0000
# Epoch 94: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1266 - accuracy: 1.0000 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 95/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3163 - accuracy: 1.0000
# Epoch 95: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3163 - accuracy: 1.0000 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 96/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 1.0000
# Epoch 96: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0821 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 1.0000
# Epoch 97/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 1.0000
# Epoch 97: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0369 - accuracy: 1.0000 - val_loss: 0.0478 - val_accuracy: 1.0000
# Epoch 98/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 1.0000
# Epoch 98: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.2662 - accuracy: 1.0000 - val_loss: 0.0456 - val_accuracy: 1.0000
# Epoch 99/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 1.0000
# Epoch 99: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.3205 - accuracy: 1.0000 - val_loss: 0.0436 - val_accuracy: 1.0000
# Epoch 100/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 1.0000
# Epoch 100: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1323 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 1.0000
# Epoch 101/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 1.0000
# Epoch 101: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 152ms/step - loss: 0.0241 - accuracy: 1.0000 - val_loss: 0.0398 - val_accuracy: 1.0000
# Epoch 102/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 1.0000
# Epoch 102: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0741 - accuracy: 1.0000 - val_loss: 0.0381 - val_accuracy: 1.0000
# Epoch 103/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 1.0000
# Epoch 103: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.0365 - val_accuracy: 1.0000
# Epoch 104/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0834 - accuracy: 1.0000
# Epoch 104: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0834 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 105/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 1.0000
# Epoch 105: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0374 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 1.0000
# Epoch 106/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 1.0000
# Epoch 106: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1871 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 1.0000
# Epoch 107/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 1.0000
# Epoch 107: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0384 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 1.0000
# Epoch 108/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 1.0000
# Epoch 108: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 109/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 1.0000
# Epoch 109: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.1058 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 1.0000
# Epoch 110/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0172 - accuracy: 1.0000
# Epoch 110: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 1.0000
# Epoch 111/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 1.0000
# Epoch 111: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0713 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 1.0000
# Epoch 112/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 1.0000
# Epoch 112: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 113/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.4300 - accuracy: 1.0000
# Epoch 113: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4300 - accuracy: 1.0000 - val_loss: 0.0241 - val_accuracy: 1.0000
# Epoch 114/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1348 - accuracy: 1.0000
# Epoch 114: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 0.1348 - accuracy: 1.0000 - val_loss: 0.0230 - val_accuracy: 1.0000
# Epoch 115/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 1.0000
# Epoch 115: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0231 - accuracy: 1.0000 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 116/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.0000
# Epoch 116: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0213 - accuracy: 1.0000 - val_loss: 0.0212 - val_accuracy: 1.0000
# Epoch 117/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0938 - accuracy: 1.0000
# Epoch 117: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0938 - accuracy: 1.0000 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 118/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 1.0000
# Epoch 118: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.1666 - accuracy: 1.0000 - val_loss: 0.0196 - val_accuracy: 1.0000
# Epoch 119/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 119: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 120/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 1.0000
# Epoch 120: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0181 - val_accuracy: 1.0000
# Epoch 121/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0608 - accuracy: 1.0000
# Epoch 121: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0608 - accuracy: 1.0000 - val_loss: 0.0175 - val_accuracy: 1.0000
# Epoch 122/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 1.0000
# Epoch 122: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0495 - accuracy: 1.0000 - val_loss: 0.0169 - val_accuracy: 1.0000
# Epoch 123/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.0000
# Epoch 123: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0163 - val_accuracy: 1.0000
# Epoch 124/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 1.0000
# Epoch 124: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.1168 - accuracy: 1.0000 - val_loss: 0.0157 - val_accuracy: 1.0000
# Epoch 125/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 1.0000
# Epoch 125: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 126/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.2174 - accuracy: 1.0000
# Epoch 126: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.2174 - accuracy: 1.0000 - val_loss: 0.0147 - val_accuracy: 1.0000
# Epoch 127/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 1.0000
# Epoch 127: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0290 - accuracy: 1.0000 - val_loss: 0.0142 - val_accuracy: 1.0000
# Epoch 128/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 1.0000
# Epoch 128: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 129/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 129: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 130/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0882 - accuracy: 1.0000
# Epoch 130: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 131/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 1.0000
# Epoch 131: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 132/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 132: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 133/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 1.0000
# Epoch 133: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0206 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 134/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 1.0000
# Epoch 134: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0115 - val_accuracy: 1.0000
# Epoch 135/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 1.0000
# Epoch 135: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 136/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0333 - accuracy: 1.0000
# Epoch 136: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.0109 - val_accuracy: 1.0000
# Epoch 137/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0588 - accuracy: 1.0000
# Epoch 137: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0588 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 138/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 1.0000
# Epoch 138: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0468 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 139/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 1.0000
# Epoch 139: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0914 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 140/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 1.0000
# Epoch 140: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0828 - accuracy: 1.0000 - val_loss: 0.0097 - val_accuracy: 1.0000
# Epoch 141/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0316 - accuracy: 1.0000
# Epoch 141: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0316 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 142/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 1.0000
# Epoch 142: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 143/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1480 - accuracy: 1.0000
# Epoch 143: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.1480 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000
# Epoch 144/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 1.0000
# Epoch 144: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 145/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 1.0000
# Epoch 145: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 146/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0466 - accuracy: 1.0000
# Epoch 146: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 93ms/step - loss: 0.0466 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 147/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0390 - accuracy: 1.0000
# Epoch 147: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0390 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 148/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 148: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000
# Epoch 149/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0794 - accuracy: 1.0000
# Epoch 149: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0794 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 150/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 1.0000
# Epoch 150: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 88ms/step - loss: 0.1739 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 151/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 1.0000
# Epoch 151: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0250 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 152/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 1.0000
# Epoch 152: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 153/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 153: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 154/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 154: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0065 - val_accuracy: 1.0000
# Epoch 155/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 155: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 156/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 1.0000
# Epoch 156: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0620 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 157/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 1.0000
# Epoch 157: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 158/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 158: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# ...
# Epoch 319: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.6865e-04 - val_accuracy: 1.0000
# Epoch 320/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 320: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.6352e-04 - val_accuracy: 1.0000
# Epoch 321/1000
# 1/1 [==============================] - ETA: 0s - loss: 4.7768e-04 - accuracy: 1.0000
# Epoch 321: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 4.7768e-04 - accuracy: 1.0000 - val_loss: 3.5899e-04 - val_accuracy: 1.0000
# Epoch 322/1000
# 1/1 [==============================] - ETA: 0s - loss: 2.9037e-04 - accuracy: 1.0000
# Epoch 322: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 79ms/step - loss: 2.9037e-04 - accuracy: 1.0000 - val_loss: 3.5494e-04 - val_accuracy: 1.0000
# Epoch 323/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 323: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 3.5065e-04 - val_accuracy: 1.0000
# Epoch 324/1000
# 1/1 [==============================] - ETA: 0s - loss: 8.9377e-04 - accuracy: 1.0000
# Epoch 324: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 8.9377e-04 - accuracy: 1.0000 - val_loss: 3.4684e-04 - val_accuracy: 1.0000
# Epoch 325/1000
# 1/1 [==============================] - ETA: 0s - loss: 2.8134e-04 - accuracy: 1.0000
# Epoch 325: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 2.8134e-04 - accuracy: 1.0000 - val_loss: 3.4338e-04 - val_accuracy: 1.0000
# Epoch 326/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.8498e-04 - accuracy: 1.0000
# Epoch 326: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 1.8498e-04 - accuracy: 1.0000 - val_loss: 3.4017e-04 - val_accuracy: 1.0000
# Epoch 327/1000
# 1/1 [==============================] - ETA: 0s - loss: 9.1105e-05 - accuracy: 1.0000
# Epoch 327: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 9.1105e-05 - accuracy: 1.0000 - val_loss: 3.3731e-04 - val_accuracy: 1.0000
# Epoch 328/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 1.0000
# Epoch 328: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 125ms/step - loss: 0.0856 - accuracy: 1.0000 - val_loss: 3.3254e-04 - val_accuracy: 1.0000
# Epoch 329/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 329: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 3.2789e-04 - val_accuracy: 1.0000
# Epoch 330/1000
# 1/1 [==============================] - ETA: 0s - loss: 3.7845e-04 - accuracy: 1.0000
# Epoch 330: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 3.7845e-04 - accuracy: 1.0000 - val_loss: 3.2360e-04 - val_accuracy: 1.0000
# Epoch 331/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 331: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.1967e-04 - val_accuracy: 1.0000
# Epoch 332/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.0469e-04 - accuracy: 1.0000
# Epoch 332: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 75ms/step - loss: 1.0469e-04 - accuracy: 1.0000 - val_loss: 3.1621e-04 - val_accuracy: 1.0000
# Epoch 333/1000
# 1/1 [==============================] - ETA: 0s - loss: 4.6094e-04 - accuracy: 1.0000
# Epoch 333: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 88ms/step - loss: 4.6094e-04 - accuracy: 1.0000 - val_loss: 3.1311e-04 - val_accuracy: 1.0000
# Epoch 334/1000
# 1/1 [==============================] - ETA: 0s - loss: 3.0905e-04 - accuracy: 1.0000
# Epoch 334: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 89ms/step - loss: 3.0905e-04 - accuracy: 1.0000 - val_loss: 3.1013e-04 - val_accuracy: 1.0000
# Epoch 335/1000
# 1/1 [==============================] - ETA: 0s - loss: 6.3842e-04 - accuracy: 1.0000
# Epoch 335: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 6.3842e-04 - accuracy: 1.0000 - val_loss: 3.0739e-04 - val_accuracy: 1.0000
# Epoch 336/1000
# 1/1 [==============================] - ETA: 0s - loss: 4.1611e-04 - accuracy: 1.0000
# Epoch 336: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 76ms/step - loss: 4.1611e-04 - accuracy: 1.0000 - val_loss: 3.0513e-04 - val_accuracy: 1.0000
# Epoch 337/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 337: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.0275e-04 - val_accuracy: 1.0000
# Epoch 338/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.5347e-04 - accuracy: 1.0000
# Epoch 338: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 86ms/step - loss: 1.5347e-04 - accuracy: 1.0000 - val_loss: 3.0072e-04 - val_accuracy: 1.0000
# Epoch 339/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.9504e-04 - accuracy: 1.0000
# Epoch 339: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 1.9504e-04 - accuracy: 1.0000 - val_loss: 2.9881e-04 - val_accuracy: 1.0000
# Epoch 340/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 340: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.9691e-04 - val_accuracy: 1.0000
# Epoch 341/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 341: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.9500e-04 - val_accuracy: 1.0000
# Epoch 342/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 1.0000
# Epoch 342: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 114ms/step - loss: 0.0354 - accuracy: 1.0000 - val_loss: 2.9226e-04 - val_accuracy: 1.0000
# Epoch 343/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 343: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 122ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.8940e-04 - val_accuracy: 1.0000
# Epoch 344/1000
# 1/1 [==============================] - ETA: 0s - loss: 5.6782e-04 - accuracy: 1.0000
# Epoch 344: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 117ms/step - loss: 5.6782e-04 - accuracy: 1.0000 - val_loss: 2.8690e-04 - val_accuracy: 1.0000
# Epoch 345/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 345: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.8451e-04 - val_accuracy: 1.0000
# Epoch 346/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 346: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.8201e-04 - val_accuracy: 1.0000
# Epoch 347/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 347: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 109ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.7975e-04 - val_accuracy: 1.0000
# Epoch 348/1000
# 1/1 [==============================] - ETA: 0s - loss: 3.4768e-04 - accuracy: 1.0000
# Epoch 348: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 90ms/step - loss: 3.4768e-04 - accuracy: 1.0000 - val_loss: 2.7772e-04 - val_accuracy: 1.0000
# Epoch 349/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.4426e-04 - accuracy: 1.0000
# Epoch 349: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 107ms/step - loss: 1.4426e-04 - accuracy: 1.0000 - val_loss: 2.7581e-04 - val_accuracy: 1.0000
# Epoch 350/1000
# 1/1 [==============================] - ETA: 0s - loss: 8.4032e-05 - accuracy: 1.0000
# Epoch 350: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 95ms/step - loss: 8.4032e-05 - accuracy: 1.0000 - val_loss: 2.7414e-04 - val_accuracy: 1.0000
# Epoch 351/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 351: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.7259e-04 - val_accuracy: 1.0000
# Epoch 352/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 1.0000
# Epoch 352: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 135ms/step - loss: 0.0166 - accuracy: 1.0000 - val_loss: 2.7009e-04 - val_accuracy: 1.0000
# Epoch 353/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 353: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 2.6783e-04 - val_accuracy: 1.0000
# Epoch 354/1000
# 1/1 [==============================] - ETA: 0s - loss: 1.0589e-04 - accuracy: 1.0000
# Epoch 354: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 72ms/step - loss: 1.0589e-04 - accuracy: 1.0000 - val_loss: 2.6544e-04 - val_accuracy: 1.0000
# Epoch 355/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 355: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 83ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.6342e-04 - val_accuracy: 1.0000
# Epoch 356/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 356: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.6127e-04 - val_accuracy: 1.0000
# Epoch 357/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 357: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 2.5925e-04 - val_accuracy: 1.0000
# Epoch 358/1000
# 1/1 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 358: saving model to model/keypoint_classifier/keypoint_classifier.hdf5
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 2.5734e-04 - val_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.fit(
#       2     X_train,
#       3     y_train,
#       4     epochs=1000,
#       5     batch_size=128,
#       6     validation_data=(X_test, y_test),
#       7     callbacks=[cp_callback, es_callback]
#       8 )
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:1850, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1845     val_logs = {
#    1846         "val_" + name: val for name, val in val_logs.items()
#    1847     }
#    1848     epoch_logs.update(val_logs)
# -> 1850 callbacks.on_epoch_end(epoch, epoch_logs)
#    1851 training_logs = epoch_logs
#    1852 if self.stop_training:
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/callbacks.py:453, in CallbackList.on_epoch_end(self, epoch, logs)
#     451 logs = self._process_logs(logs)
#     452 for callback in self.callbacks:
# --> 453     callback.on_epoch_end(epoch, logs)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/callbacks.py:1104, in ProgbarLogger.on_epoch_end(self, epoch, logs)
#    1103 def on_epoch_end(self, epoch, logs=None):
# -> 1104     self._finalize_progbar(logs, self._train_step)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/callbacks.py:1181, in ProgbarLogger._finalize_progbar(self, logs, counter)
#    1179     self.target = counter or self.seen
#    1180     self.progbar.target = self.target
# -> 1181 self.progbar.update(self.target, list(logs.items()), finalize=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/generic_utils.py:296, in Progbar.update(self, current, values, finalize)
#     293         info += "\n"
#     295     message += info
# --> 296     io_utils.print_msg(message, line_break=False)
#     297     message = ""
#     299 elif self.verbose == 2:
#
# File ~/anaconda3/lib/python3.11/site-packages/keras/src/utils/io_utils.py:81, in print_msg(message, line_break)
#      79     else:
#      80         sys.stdout.write(message)
# ---> 81     sys.stdout.flush()
#      82 else:
#      83     logging.info(message)
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/iostream.py:564, in OutStream.flush(self)
#     562     self.pub_thread.schedule(evt.set)
#     563     # and give a timeout to avoid
# --> 564     if not evt.wait(self.flush_timeout):
#     565         # write directly to __stderr__ instead of warning because
#     566         # if this is happening sys.stderr may be the problem.
#     567         print("IOStream.flush timed out", file=sys.__stderr__)
#     568 else:
#
# File ~/anaconda3/lib/python3.11/threading.py:622, in Event.wait(self, timeout)
#     620 signaled = self._flag
#     621 if not signaled:
# --> 622     signaled = self._cond.wait(timeout)
#     623 return signaled
#
# File ~/anaconda3/lib/python3.11/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# モデル評価
val_loss, val_acc = model.evaluate(X_test, y_test, batch_size=128)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2031 - accuracy: 0.9574

# %%
# 保存したモデルのロード
model = tf.keras.models.load_model(model_save_path)

# %%
# 推論テスト
predict_result = model.predict(np.array([X_test[0]]))
print(np.squeeze(predict_result))
print(np.argmax(np.squeeze(predict_result)))
# Out:
# 1/1 [==============================] - 0s 104ms/step
# [9.7698373e-01 2.2930967e-02 7.9446385e-05 5.8320188e-06]
# 0

# %% [markdown]
# # 混同行列 (Confusion Matrix)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def print_confusion_matrix(y_true, y_pred, report=True):
    labels = sorted(list(set(y_true)))
    cmx_data = confusion_matrix(y_true, y_pred, labels=labels)
    
    df_cmx = pd.DataFrame(cmx_data, index=labels, columns=labels)
 
    fig, ax = plt.subplots(figsize=(7, 6))
    sns.heatmap(df_cmx, annot=True, fmt='g' ,square=False)
    ax.set_ylim(len(set(y_true)), 0)
    plt.show()
    
    if report:
        print('Classification Report')
        print(classification_report(y_test, y_pred))

Y_pred = model.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

print_confusion_matrix(y_test, y_pred)
# Out:
# 38/38 [==============================] - 0s 2ms/step
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       402
#            1       0.98      0.88      0.93       366
#            2       0.90      0.99      0.94       343
#            3       1.00      0.99      0.99        86
#
#     accuracy                           0.96      1197
#    macro avg       0.97      0.96      0.96      1197
# weighted avg       0.96      0.96      0.96      1197

# %% [markdown]
# # Tensorflow-Lite用のモデルへ変換

# %%
# 推論専用のモデルとして保存
model.save(model_save_path, include_optimizer=False)
# Out:
# /Users/yoon/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# モデルを変換(量子化)
tflite_save_path = 'model/keypoint_classifier/keypoint_classifier.tflite'

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantized_model = converter.convert()

open(tflite_save_path, 'wb').write(tflite_quantized_model)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/m1/nzwkx_t91v1c1lzszjqmggc80000gn/T/tmpv9z3arlo/assets
# INFO:tensorflow:Assets written to: /var/folders/m1/nzwkx_t91v1c1lzszjqmggc80000gn/T/tmpv9z3arlo/assets
# 2023-12-19 20:51:29.311103: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:378] Ignored output_format.
# 2023-12-19 20:51:29.311523: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:381] Ignored drop_control_dependency.
# 2023-12-19 20:51:29.313569: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /var/folders/m1/nzwkx_t91v1c1lzszjqmggc80000gn/T/tmpv9z3arlo
# 2023-12-19 20:51:29.315892: I tensorflow/cc/saved_model/reader.cc:51] Reading meta graph with tags { serve }
# 2023-12-19 20:51:29.315912: I tensorflow/cc/saved_model/reader.cc:146] Reading SavedModel debug info (if present) from: /var/folders/m1/nzwkx_t91v1c1lzszjqmggc80000gn/T/tmpv9z3arlo
# 2023-12-19 20:51:29.322351: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# 2023-12-19 20:51:29.324114: I tensorflow/cc/saved_model/loader.cc:233] Restoring SavedModel bundle.
# 2023-12-19 20:51:29.402911: I tensorflow/cc/saved_model/loader.cc:217] Running initialization op on SavedModel bundle at path: /var/folders/m1/nzwkx_t91v1c1lzszjqmggc80000gn/T/tmpv9z3arlo
# 2023-12-19 20:51:29.425230: I tensorflow/cc/saved_model/loader.cc:316] SavedModel load for tags { serve }; Status: success: OK. Took 111821 microseconds.
# 2023-12-19 20:51:29.495416: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 6544

# %% [markdown]
# # 推論テスト

# %%
interpreter = tf.lite.Interpreter(model_path=tflite_save_path)
interpreter.allocate_tensors()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# 入出力テンソルを取得
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# %%
interpreter.set_tensor(input_details[0]['index'], np.array([X_test[0]]))

# %%
# %%time
# 推論実施
interpreter.invoke()
tflite_results = interpreter.get_tensor(output_details[0]['index'])
# Out:
# CPU times: user 737 µs, sys: 1.53 ms, total: 2.26 ms
# Wall time: 1.85 ms

# %%
print(np.squeeze(tflite_results))
print(np.argmax(np.squeeze(tflite_results)))
# Out:
# [9.7698373e-01 2.2930980e-02 7.9446392e-05 5.8320247e-06]
# 0
